# %%
import os
import warnings
warnings.simplefilter(action = 'ignore', category=FutureWarning)
warnings.filterwarnings('ignore')
def ignore_warn(*args, **kwargs):
    pass

warnings.warn = ignore_warn #ignore annoying warning (from sklearn and seaborn)

import pandas as pd
import datetime
import math
import numpy as np
import matplotlib.pyplot as plt
import itertools
import statsmodels.api as sm

# %%
trans= pd.read_csv('/Users/mubinaarastu/Machine Learning Models/Dataset/transactions.csv')

# %%
trans.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
trans['date'].min()
# Out:
# '2013-01-01'

# %%
trans['date'].max()
# Out:
# '2017-08-15'

# %%
trans.isnull().sum()
# Out:
# date            0
# store_nbr       0
# transactions    0
# dtype: int64

# %% [markdown]
# Our current datetime data can be tricky to work with, therefore, we will use the average daily sales value for that month instead, and we are using the start of each month as the timestamp.

# %%
trans.dtypes
# Out:
# date            object
# store_nbr        int64
# transactions     int64
# dtype: object

# %%
trans['date'] =  pd.to_datetime(trans['date'], format="%Y/%m/%d")

# %%
trans.dtypes
# Out:
# date            datetime64[ns]
# store_nbr                int64
# transactions             int64
# dtype: object

# %%
trans=trans.groupby("date")['transactions'].sum().reset_index()

# %%
trans=trans.sort_values('date')
trans.head()
# Out:
#         date  transactions
# 0 2013-01-01           770
# 1 2013-01-02         93215
# 2 2013-01-03         78504
# 3 2013-01-04         78494
# 4 2013-01-05         93573

# %%
trans= trans.set_index('date')
trans.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10',
#                ...
#                '2017-08-06', '2017-08-07', '2017-08-08', '2017-08-09',
#                '2017-08-10', '2017-08-11', '2017-08-12', '2017-08-13',
#                '2017-08-14', '2017-08-15'],
#               dtype='datetime64[ns]', name='date', length=1682, freq=None)

# %%
y = trans['transactions'].resample('M').mean()
y
# Out:
# date
# 2013-01-31     73856.709677
# 2013-02-28     77486.250000
# 2013-03-31     79312.354839
# 2013-04-30     78163.500000
# 2013-05-31     79595.645161
# 2013-06-30     79740.200000
# 2013-07-31     77482.838710
# 2013-08-31     79391.580645
# 2013-09-30     79348.733333
# 2013-10-31     77691.612903
# 2013-11-30     78995.533333
# 2013-12-31     98762.200000
# 2014-01-31     77210.580645
# 2014-02-28     81363.107143
# 2014-03-31     82110.548387
# 2014-04-30     81855.533333
# 2014-05-31     80750.387097
# 2014-06-30     79971.466667
# 2014-07-31     78785.193548
# 2014-08-31     81857.161290
# 2014-09-30     81637.700000
# 2014-10-31     80751.935484
# 2014-11-30     81676.600000
# 2014-12-31    101636.100000
# 2015-01-31     80292.225806
# 2015-02-28     83785.142857
# 2015-03-31     84693.548387
# 2015-04-30     84445.166667
# 2015-05-31     86255.193548
# 2015-06-30     84363.433333
# 2015-07-31     84025.290323
# 2015-08-31     86292.161290
# 2015-09-30     84841.733333
# 2015-10-31     84209.161290
# 2015-11-30     84273.100000
# 2015-12-31    104996.266667
# 2016-01-31     81765.689655
# 2016-02-29     85027.517241
# 2016-03-31     84118.000000
# 2016-04-30     87726.566667
# 2016-05-31     86005.064516
# 2016-06-30     83035.433333
# 2016-07-31     83680.225806
# 2016-08-31     81810.032258
# 2016-09-30     81232.466667
# 2016-10-31     81483.870968
# 2016-11-30     84317.200000
# 2016-12-31    106532.366667
# 2017-01-31     84285.419355
# 2017-02-28     87441.785714
# 2017-03-31     86472.419355
# 2017-04-30     88926.933333
# 2017-05-31     90383.354839
# 2017-06-30     88962.100000
# 2017-07-31     89807.290323
# 2017-08-31     89046.133333
# Freq: M, Name: transactions, dtype: float64

# %%
y['2017':]
# Out:
# date
# 2017-01-31    84285.419355
# 2017-02-28    87441.785714
# 2017-03-31    86472.419355
# 2017-04-30    88926.933333
# 2017-05-31    90383.354839
# 2017-06-30    88962.100000
# 2017-07-31    89807.290323
# 2017-08-31    89046.133333
# Freq: M, Name: transactions, dtype: float64

# %%
y.plot(figsize=(15, 6))
plt.show()

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8

decomposition = sm.tsa.seasonal_decompose(y, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# ## Time series forecasting with ARIMA
#
# We are going to apply one of the most commonly used method for time-series forecasting, known as ARIMA, which stands for Autoregressive Integrated Moving Average.
#
# Parameter Selection for the ARIMA Time Series Model

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.25366D+01    |proj g|=  4.93827D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   4.938D-08   1.254D+01
#   F =   12.536637949741822
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:1406.1034503710841
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.55144D+02    |proj g|=  6.71237D+01
#
# At iterate    5    f=  9.56489D+00    |proj g|=  1.56136D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      7     10      1     0     0   5.949D-06   9.565D+00
#   F =   9.5648842587279557
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:1075.267036977531
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.31934D+00    |proj g|=  7.15371D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      3      7      1     0     0   2.070D-06   7.307D+00
#   F =   7.3073347736217231
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:820.421494645633
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.05980D+01    |proj g|=  1.16892D-04
#   ys=-3.348E+01  -gs= 5.447E-01 BFGS update SKIPPED
#   ys=-1.630E+01  -gs= 5.359E-01 BFGS update SKIPPED
#
# At iterate    5    f=  8.37171D+00    |proj g|=  1.09675D+05
#   ys=-6.556E+00  -gs= 5.238E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6    101      3     3     0   1.097D+05   8.372D+00
#   F =   8.3717103809126083
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:941.6315626622122
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.23937D+00    |proj g|=  4.62174D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     13      1     0     0   4.621D-03   7.239D+00
#   F =   7.2393702663714787
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:814.8094698336056
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.35469D+02    |proj g|=  1.27259D+03
#
# At iterate    5    f=  9.84678D+00    |proj g|=  6.38332D+01
#
# At iterate   10    f=  7.08708D+00    |proj g|=  8.67855D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     11     34      1     0     0   8.679D-05   7.087D+00
#   F =   7.0870815160376903
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:799.7531297962213
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.46899D+00    |proj g|=  2.14735D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   2.147D-06   5.469D+00
#   F =   5.4689873250218417
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:616.5265804024463
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.34611D+01    |proj g|=  1.42950D-04
#   ys=-4.882E+01  -gs= 5.474E-01 BFGS update SKIPPED
#   ys=-2.800E+01  -gs= 5.430E-01 BFGS update SKIPPED
#   ys=-1.192E+01  -gs= 5.300E-01 BFGS update SKIPPED
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  1.14885D+01    |proj g|=  9.31608D+04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6    129      4     3     0   9.316D+04   1.149D+01
#   F =   11.488451867766951
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:1292.7066091898985
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.21234D+01    |proj g|=  4.53839D-01
#
# At iterate    5    f=  1.19854D+01    |proj g|=  2.51319D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6     11      1     0     0   7.704D-06   1.199D+01
#   F =   11.985379250465456
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:1346.3624760521311
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.38649D+02    |proj g|=  7.55142D+01
#
# At iterate    5    f=  9.73680D+00    |proj g|=  1.77124D-01
#
# At iterate   10    f=  9.70296D+00    |proj g|=  6.45170D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     12     19      1     0     0   9.159D-06   9.703D+00
#   F =   9.7029568416907939
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:1092.731166269369
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.60968D+00    |proj g|=  5.92278D+00
#
# At iterate    5    f=  6.98713D+00    |proj g|=  2.20846D-01
#
# At iterate   10    f=  6.97902D+00    |proj g|=  6.95231D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     10     11      1     0     0   6.952D-05   6.979D+00
#   F =   6.9790203969219586
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:785.6502844552593
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.96985D+01    |proj g|=  1.75432D-04
#   ys=-3.788E+01  -gs= 5.283E-01 BFGS update SKIPPED
#   ys=-1.767E+01  -gs= 5.204E-01 BFGS update SKIPPED
#   ys=-1.649E+02  -gs= 5.340E-01 BFGS update SKIPPED
#
# At iterate    5    f=  9.90643D+00    |proj g|=  1.33950D+04
#   ys=-1.893E+00  -gs= 5.027E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      7    134      4     4     0   6.384D+04   8.452D+00
#   F =   8.4517138147371487
#
# ABNORMAL_TERMINATION_IN_LNSRCH
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:952.5919472505606
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.64049D+00    |proj g|=  4.29776D-03
#
# At iterate    5    f=  9.63992D+00    |proj g|=  7.61050D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6     10      1     0     0   9.243D-06   9.640D+00
#   F =   9.6399201193524640
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:1085.671053367476
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.58353D+01    |proj g|=  2.49224D+01
#
# At iterate    5    f=  9.22789D+00    |proj g|=  1.18081D-01
#
# At iterate   10    f=  9.20351D+00    |proj g|=  4.15776D-02
#
# At iterate   15    f=  9.20204D+00    |proj g|=  2.04281D-03
#
# At iterate   20    f=  9.20168D+00    |proj g|=  1.15302D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     23     29      1     0     0   8.825D-06   9.202D+00
#   F =   9.2016755467200788
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:1038.5876612326488
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.34793D+00    |proj g|=  7.59436D-01
#
# At iterate    5    f=  5.29640D+00    |proj g|=  1.81323D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      7      9      1     0     0   6.550D-05   5.296D+00
#   F =   5.2964016010580002
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:599.196979318496
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.25770D+01    |proj g|=  1.75433D-04
#   ys=-3.788E+01  -gs= 5.283E-01 BFGS update SKIPPED
#  This problem is unconstrained.
#  This problem is unconstrained.
#   ys=-1.768E+01  -gs= 5.204E-01 BFGS update SKIPPED
#   ys=-9.748E+01  -gs= 5.328E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      5     89      3     3     0   1.007D+04   1.306D+01
#   F =   13.055570930974813
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:1470.2239442691791
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00827D+01    |proj g|=  3.90230D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   3.902D-06   1.008D+01
#   F =   10.082717337396206
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:1131.264341788375
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.88600D+01    |proj g|=  1.49876D+01
#
# At iterate    5    f=  7.55543D+00    |proj g|=  1.79084D-01
#
# At iterate   10    f=  7.53813D+00    |proj g|=  2.74000D-03
#
# At iterate   15    f=  7.53299D+00    |proj g|=  1.13504D-01
#
# At iterate   20    f=  7.42577D+00    |proj g|=  1.73541D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     24     31      1     0     0   5.285D-08   7.423D+00
#   F =   7.4233907330145401
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:835.4197620976284
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.61635D+00    |proj g|=  1.77895D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      3      6      1     0     0   8.709D-06   6.600D+00
#   F =   6.5996073614823745
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:741.1560244860259
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.16131D+01    |proj g|=  3.48436D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5     84      2     0     0   2.569D+04   1.100D+01
#   F =   10.999412260514365
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:1235.934173177609
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.74845D+00    |proj g|=  9.96403D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     21      1     0     0   9.964D-05   6.748D+00
#   F =   6.7484518812246881
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:759.826610697165
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.83828D+01    |proj g|=  1.61637D+01
#
# At iterate    5    f=  1.14845D+01    |proj g|=  2.25027D+00
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   10    f=  6.68854D+00    |proj g|=  6.16010D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     14     23      1     0     0   5.768D-04   6.688D+00
#   F =   6.6882655827128081
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:755.0857452638345
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.86677D+00    |proj g|=  2.84874D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   2.849D-06   4.867D+00
#   F =   4.8667749223563499
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:549.0787913039112
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.14938D+01    |proj g|=  7.12522D-04
#   ys=-3.685E+01  -gs= 5.281E-01 BFGS update SKIPPED
#   ys=-4.859E+01  -gs= 5.299E-01 BFGS update SKIPPED
#   ys=-1.808E+01  -gs= 5.207E-01 BFGS update SKIPPED
#   ys=-2.131E+01  -gs= 5.229E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      5     64      5     4     0   6.971D+03   1.284D+01
#   F =   12.835589981105906
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:1443.5860778838614
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.60529D+00    |proj g|=  9.40209D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      7      1     0     0   1.252D-05   9.605D+00
#   F =   9.6045475709150487
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:1079.7093279424855
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.45553D+01    |proj g|=  1.14716D+01
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  7.34189D+00    |proj g|=  1.49560D-01
#
# At iterate   10    f=  7.31843D+00    |proj g|=  7.54582D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     10     11      1     0     0   7.546D-05   7.318D+00
#   F =   7.3184303510538031
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:825.6641993180259
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.43413D+00    |proj g|=  2.58504D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   8.402D-06   6.434D+00
#   F =   6.4338939138815610
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:724.5961183547348
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.09055D+01    |proj g|=  3.28610D-04
#   ys=-1.070E+02  -gs= 5.154E-01 BFGS update SKIPPED
#   ys=-1.364E+01  -gs= 4.996E-01 BFGS update SKIPPED
#   ys=-6.971E+01  -gs= 5.141E-01 BFGS update SKIPPED
#   ys=-1.350E+01  -gs= 4.994E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      5     65      5     4     0   7.423D+03   1.210D+01
#   F =   12.099033693077610
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:1361.0917736246922
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.29140D+00    |proj g|=  4.37553D+00
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  7.46329D+00    |proj g|=  1.18408D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      7      8      1     0     0   1.120D-04   7.463D+00
#   F =   7.4632889792583130
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:841.888365676931
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.11433D+01    |proj g|=  1.46937D+01
#
# At iterate    5    f=  7.24098D+00    |proj g|=  4.02042D-01
#
# At iterate   10    f=  7.14517D+00    |proj g|=  2.60522D-01
#
# At iterate   15    f=  7.11613D+00    |proj g|=  4.49926D-03
#
# At iterate   20    f=  7.11602D+00    |proj g|=  2.54684D-04
#
# At iterate   25    f=  7.11597D+00    |proj g|=  2.70352D-03
#
# At iterate   30    f=  7.10290D+00    |proj g|=  1.16416D-01
#
# At iterate   35    f=  6.65756D+00    |proj g|=  2.34983D+00
#
# At iterate   40    f=  6.42685D+00    |proj g|=  5.01770D-02
#
# At iterate   45    f=  6.42656D+00    |proj g|=  5.26643D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     45     65      1     0     0   5.266D-05   6.427D+00
#   F =   6.4265620731517696
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:727.7749521929982
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.94771D+00    |proj g|=  8.92902D-01
#
# At iterate    5    f=  4.86672D+00    |proj g|=  3.09362D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      9     11      1     0     0   6.635D-06   4.867D+00
#   F =   4.8666211806549269
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:551.0615722333519
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.11605D+01    |proj g|=  3.28610D-04
#  This problem is unconstrained.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#   ys=-1.070E+02  -gs= 5.154E-01 BFGS update SKIPPED
#   ys=-1.363E+01  -gs= 4.996E-01 BFGS update SKIPPED
#   ys=-6.985E+01  -gs= 5.141E-01 BFGS update SKIPPED
#   ys=-1.632E+01  -gs= 5.024E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      5     65      5     4     0   8.885D+03   1.225D+01
#   F =   12.253512142013539
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:1380.3933599055165
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.02617D+01    |proj g|=  5.01555D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     14      1     0     0   5.014D-04   1.026D+01
#   F =   10.261695444697196
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:1153.309889806086
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.40954D+01    |proj g|=  7.75155D-01
#
# At iterate    5    f=  7.77411D+00    |proj g|=  6.58287D-01
#
# At iterate   10    f=  7.76598D+00    |proj g|=  1.10093D-02
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     13     26      1     0     0   6.180D-05   7.766D+00
#   F =   7.7659784921789665
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:875.7895911240443
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.73903D+00    |proj g|=  1.53760D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     11      1     0     0   1.535D-05   6.739D+00
#   F =   6.7390286857610979
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:758.771212805243
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.99861D+01    |proj g|=  3.53074D-04
#   ys=-8.396E+01  -gs= 5.480E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      4     77      2     1     0   1.853D+05   7.668D+00
#   F =   7.6679194519362452
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:864.8069786168595
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.65291D+00    |proj g|=  1.61404D-02
#
# At iterate    5    f=  7.65191D+00    |proj g|=  3.06477D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      8     11      1     0     0   8.889D-05   7.652D+00
#   F =   7.6519095563163164
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:863.0138703074274
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.19420D+01    |proj g|=  6.06799D+01
#
# At iterate    5    f=  8.23895D+00    |proj g|=  2.30980D+00
#
# At iterate   10    f=  7.65777D+00    |proj g|=  9.02590D-02
#
# At iterate   15    f=  7.65181D+00    |proj g|=  3.71555D-03
#
# At iterate   20    f=  7.65170D+00    |proj g|=  8.57666D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     22     25      1     0     0   8.894D-05   7.652D+00
#   F =   7.6516979892778796
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:864.9901747991225
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.95404D+00    |proj g|=  3.30776D-01
#
# At iterate    5    f=  4.85602D+00    |proj g|=  2.99405D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      5      7      1     0     0   2.994D-06   4.856D+00
#   F =   4.8560225806678714
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:549.8745290348016
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.29605D+01    |proj g|=  3.53073D-04
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#   ys=-2.538E+01  -gs= 5.408E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      5     94      2     1     0   5.708D+04   1.177D+01
#   F =   11.774774045717065
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:1326.7746931203112
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.79143D+00    |proj g|=  4.62651D-01
#
# At iterate    5    f=  9.79006D+00    |proj g|=  1.88817D+00
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
# At iterate   10    f=  9.75827D+00    |proj g|=  2.65959D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     14     39      1     0     0   9.589D-03   9.758D+00
#   F =   9.7579968185427255
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:1098.8956436767853
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.37705D+01    |proj g|=  6.91263D+00
#
# At iterate    5    f=  8.01905D+00    |proj g|=  1.42290D+01
#
# At iterate   10    f=  7.53548D+00    |proj g|=  1.95843D+00
#
# At iterate   15    f=  7.46332D+00    |proj g|=  3.24285D-01
#
# At iterate   20    f=  7.43701D+00    |proj g|=  1.89852D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     22     41      1     0     0   1.088D-03   7.437D+00
#   F =   7.4370110939598622
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:840.9452425235046
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.60332D+00    |proj g|=  4.27804D-01
#
# At iterate    5    f=  6.58503D+00    |proj g|=  9.98006D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      7      9      1     0     0   1.235D-05   6.585D+00
#   F =   6.5850304413758414
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:743.5234094340942
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.93501D+01    |proj g|=  3.36184D-04
#   ys=-6.018E+01  -gs= 5.310E-01 BFGS update SKIPPED
#  This problem is unconstrained.
#  This problem is unconstrained.
#   ys=-3.446E+01  -gs= 5.276E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      5     89      2     2     0   8.508D+03   1.017D+01
#   F =   10.174829768263935
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ...
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.58244D+00    |proj g|=  3.89013D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   3.890D-06   6.582D+00
#   F =   6.5824410197797425
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:741.2333942153311
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.16237D+01    |proj g|=  3.41623D-04
#   ys=-2.558E+01  -gs= 5.249E-01 BFGS update SKIPPED
#   ys=-9.475E+00  -gs= 5.119E-01 BFGS update SKIPPED
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      5     95      2     2     0   1.186D+05   1.027D+01
#   F =   10.272507095945612
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:1156.5207947459085
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.35997D+00    |proj g|=  1.22513D-02
#
# At iterate    5    f=  7.35800D+00    |proj g|=  1.00532D-04
#
# At iterate   10    f=  7.35799D+00    |proj g|=  2.05456D-03
#
# At iterate   15    f=  7.35760D+00    |proj g|=  2.50490D-02
#
# At iterate   20    f=  7.32892D+00    |proj g|=  2.09377D-01
#
# At iterate   25    f=  7.13544D+00    |proj g|=  2.32698D-01
#
# At iterate   30    f=  6.58787D+00    |proj g|=  2.24698D-01
#
# At iterate   35    f=  6.58220D+00    |proj g|=  6.14441D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     36     46      1     0     0   4.664D-05   6.582D+00
#   F =   6.5822014391075703
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:743.2065611800479
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.99006D+01    |proj g|=  9.66260D+00
#
# At iterate    5    f=  7.37695D+00    |proj g|=  3.79658D-02
#
# At iterate   10    f=  7.35872D+00    |proj g|=  2.97076D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     14     15      1     0     0   1.006D-04   7.358D+00
#   F =   7.3578120119901111
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:832.0749453428924
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.70383D+00    |proj g|=  1.04596D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      4      6      1     0     0   2.398D-06   4.704D+00
#   F =   4.7036236746482567
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:532.8058515606048
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.18876D+01    |proj g|=  3.41624D-04
#   ys=-2.498E+01  -gs= 5.247E-01 BFGS update SKIPPED
#   ys=-1.151E+01  -gs= 5.086E-01 BFGS update SKIPPED
#
# At iterate    5    f=  1.10040D+01    |proj g|=  6.30379D+04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      6    106      2     2     0   6.304D+04   1.100D+01
#   F =   11.004000202377981
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:1240.4480226663338
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.60725D+00    |proj g|=  6.84119D-02
#
# At iterate    5    f=  9.60220D+00    |proj g|=  7.23455D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      7     10      1     0     0   1.335D-05   9.602D+00
#   F =   9.6022048851548085
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:1081.4469471373386
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.45549D+01    |proj g|=  1.12745D+01
#
# At iterate    5    f=  7.40153D+00    |proj g|=  2.91811D-01
#
# At iterate   10    f=  7.24897D+00    |proj g|=  1.54714D-01
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   15    f=  7.23607D+00    |proj g|=  4.45476D-02
#
# At iterate   20    f=  7.23331D+00    |proj g|=  5.46996D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     23     32      1     0     0   7.067D-05   7.233D+00
#   F =   7.2332804536393009
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:818.1274108076017
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.42498D+00    |proj g|=  6.37201D-03
#
# At iterate    5    f=  6.42493D+00    |proj g|=  4.85824D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      9      1     0     0   4.560D-06   6.425D+00
#   F =   6.4249275739008080
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:725.5918882768905
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.09036D+01    |proj g|=  3.29806D-04
#   ys=-6.600E+02  -gs= 5.175E-01 BFGS update SKIPPED
#   ys=-8.577E+00  -gs= 4.672E-01 BFGS update SKIPPED
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      5     78      3     2     0   1.928D+05   9.215D+00
#   F =   9.2152661875115545
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:1040.109813001294
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.73924D+00    |proj g|=  2.91925D+00
#
# At iterate    5    f=  7.29219D+00    |proj g|=  2.13377D-02
#
# At iterate   10    f=  7.28970D+00    |proj g|=  7.05342D-03
#
# At iterate   15    f=  7.28873D+00    |proj g|=  9.46571D-03
#
# At iterate   20    f=  7.28865D+00    |proj g|=  1.09679D-04
#
# At iterate   25    f=  7.28858D+00    |proj g|=  4.03398D-03
#
# At iterate   30    f=  7.28360D+00    |proj g|=  2.65782D-02
#
# At iterate   35    f=  6.90058D+00    |proj g|=  1.44514D+00
#
# At iterate   40    f=  6.58564D+00    |proj g|=  1.82756D-01
#
# At iterate   45    f=  6.57694D+00    |proj g|=  1.78947D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     48     62      1     0     0   6.262D-06   6.577D+00
#   F =   6.5769440552770293
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:744.6177341910272
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.10188D+01    |proj g|=  1.43126D+01
#
# At iterate    5    f=  7.37405D+00    |proj g|=  2.50963D-01
#
# At iterate   10    f=  7.32253D+00    |proj g|=  2.44892D-01
#
# At iterate   15    f=  7.25124D+00    |proj g|=  2.55645D-01
#
# At iterate   20    f=  7.12135D+00    |proj g|=  9.46764D-02
#
# At iterate   25    f=  7.11637D+00    |proj g|=  2.13284D-02
#
# At iterate   30    f=  7.11606D+00    |proj g|=  3.64627D-03
#
# At iterate   35    f=  7.11553D+00    |proj g|=  1.06537D-03
#
# At iterate   40    f=  7.11516D+00    |proj g|=  1.13821D-03
#
# At iterate   45    f=  7.11515D+00    |proj g|=  3.44698D-04
#
# At iterate   50    f=  7.11510D+00    |proj g|=  5.27624D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     50     63      1     0     0   5.276D-03   7.115D+00
#   F =   7.1151018427250525
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:806.8914063852059
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.71276D+00    |proj g|=  8.63149D-02
#
# At iterate    5    f=  4.70325D+00    |proj g|=  1.25320D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      9     12      1     0     0   1.484D-05   4.703D+00
#   F =   4.7030327671057348
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:534.7396699158423
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.11587D+01    |proj g|=  3.29807D-04
#   ys=-6.601E+02  -gs= 5.175E-01 BFGS update SKIPPED
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  1.10320D+01    |proj g|=  1.05881D+03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      8     43      2     1     0   1.776D-10   1.103D+01
#   F =   11.026774889944686
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:1244.9987876738048

# %%
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.71276D+00    |proj g|=  8.63149D-02
#
# At iterate    5    f=  4.70325D+00    |proj g|=  1.25320D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      9     12      1     0     0   1.484D-05   4.703D+00
#   F =   4.7030327671057348
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2876      0.789     -0.365      0.715      -1.834       1.259
# ma.L1          0.0579      0.826      0.070      0.944      -1.561       1.677
# ar.S.L12      -0.4828      0.261     -1.853      0.064      -0.993       0.028
# sigma2      2.465e+06   6.45e+05      3.820      0.000     1.2e+06    3.73e+06
# ==============================================================================
#  This problem is unconstrained.

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %% [markdown]
# ### Validate Forecasting

# %% [markdown]
# To help us understand the accuracy of our forecasts, we compare predicted sales to real sales of the time series, and we set forecasts to start at 2017-07-01 to the end of the data.

# %%
pred = results.get_prediction(start=pd.to_datetime('2016-01-31'), dynamic=False)
pred_ci = pred.conf_int()

ax = y['2013':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(10, 7))

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Date')
ax.set_ylabel('Transactions')
plt.legend()

plt.show()

# %% [markdown]
# ***The line plot is showing the observed values compared to the rolling forecast predictions. Overall, our forecasts align with the true values very well, showing an upward trend starts from the beginning of the year.***

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2016-01-31':]

# Compute the mean square error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 3261279.92

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 1805.9

# %%
pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()

ax = y.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Furniture Sales')

plt.legend()
plt.show()

# %%
##!conda install -c conda-forge fbprophet -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: / ^C
# failed
#
# CondaError: KeyboardInterrupt

# %%
from fbprophet import Prophet

transac = trans.rename(columns={'date': 'ds', 'transactions': 'y'})
transac_model = Prophet(interval_width=0.95)
transac_model.fit(transac)
